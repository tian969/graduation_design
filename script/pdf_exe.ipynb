# %%
from PyPDF2 import PdfReader

pdf_path = "/Users/tianzujie.1/DevRepo/graduation_design/doc/example/thesis.pdf"
reader = PdfReader(pdf_path)

print("页数:", len(reader.pages))
print("第一页内容:")
print(reader.pages[0].extract_text())
# Out:
# 运行具有“py310 (Python 3.10.0)”的单元格需要ipykernel包。
#
# 使用所需的包 <a href='command:jupyter.createPythonEnvAndSelectController'>创建 Python 环境</a>。
